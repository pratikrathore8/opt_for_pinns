# %%
import random
import torch
import torch.nn as nn
import numpy as np
from scipy.stats import ortho_group
import matplotlib.pyplot as plt

# %%
# set seeds
seed = 0
np.random.seed(seed)
random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

# %%
import torch
from torch.optim import Optimizer
from torch.func import vmap
from functools import reduce


def _armijo(f, x, gx, dx, t, alpha=0.1, beta=0.5):
    f0 = f(x, 0, dx)
    f1 = f(x, t, dx)
    while f1 > f0 + alpha * t * gx.dot(dx):
        t *= beta
        f1 = f(x, t, dx)
    return t


def _apply_nys_precond_inv(U, S_mu_inv, mu, lambd_r, x):
    z = U.T @ x
    z = (lambd_r + mu) * (U @ (S_mu_inv * z)) + (x - U @ z)
    return z


def _nystrom_pcg(hess, b, x, mu, U, S, r, tol, max_iters):
    lambd_r = S[r - 1]
    S_mu_inv = (S + mu) ** (-1)

    resid = b - (hess(x) + mu * x)
    z = _apply_nys_precond_inv(U, S_mu_inv, mu, lambd_r, resid)
    p = z.clone()

    i = 0

    while torch.norm(resid) > tol and i < max_iters:
        v = hess(p) + mu * p
        alpha = torch.dot(resid, z) / torch.dot(p, v)
        x += alpha * p

        rTz = torch.dot(resid, z)
        resid -= alpha * v
        z = _apply_nys_precond_inv(U, S_mu_inv, mu, lambd_r, resid)
        beta = torch.dot(resid, z) / rTz

        p = z + beta * p

        if i % 100 == 0:
            print(
                f"PCG iteration {i} complete. Residual norm = {torch.norm(resid)}")
        i += 1

    if torch.norm(resid) > tol:
        print(
            f"Warning: PCG did not converge to tolerance. Tolerance was {tol} but norm of residual is {torch.norm(resid)}")

    return x


class NysNewtonCG(Optimizer):
    def __init__(self, params, lr=1.0, rank=10, mu=1e-4, chunk_size=1,
                 cg_tol=1e-16, cg_max_iters=1000, line_search_fn=None, verbose=False):
        defaults = dict(lr=lr, rank=rank, chunk_size=chunk_size, mu=mu, cg_tol=cg_tol,
                        cg_max_iters=cg_max_iters, line_search_fn=line_search_fn)
        self.rank = rank
        self.mu = mu
        self.chunk_size = chunk_size
        self.cg_tol = cg_tol
        self.cg_max_iters = cg_max_iters
        self.line_search_fn = line_search_fn
        self.verbose = verbose
        self.U = None
        self.S = None
        self.n_iters = 0
        super(NysNewtonCG, self).__init__(params, defaults)

        if len(self.param_groups) > 1:
            raise ValueError(
                "NysNewtonCG doesn't currently support per-parameter options (parameter groups)")

        if self.line_search_fn is not None and self.line_search_fn != 'armijo':
            raise ValueError("NysNewtonCG only supports Armijo line search")

        self._params = self.param_groups[0]['params']
        self._params_list = list(self._params)
        self._numel_cache = None

    def step(self, closure=None):
        if self.n_iters == 0:
            # Store the previous direction for warm starting PCG
            self.old_dir = torch.zeros(
                self._numel(), device=self._params[0].device)

        loss = None
        if closure is not None:
            with torch.enable_grad():
                loss, grad_tuple = closure()

        g = torch.cat([grad.view(-1)
                      for grad in grad_tuple if grad is not None])

        # g = torch.cat([p.grad.view(-1)
        #               for group in self.param_groups for p in group['params'] if p.grad is not None])
        # g = g.detach()

        # one step update
        for group_idx, group in enumerate(self.param_groups):
            def hvp_temp(x):
                return self._hvp(g, self._params_list, x)

            # Calculate the Newton direction
            d = _nystrom_pcg(hvp_temp, g, self.old_dir,
                             self.mu, self.U, self.S, self.rank, self.cg_tol, self.cg_max_iters)

            # Store the previous direction for warm starting PCG
            self.old_dir = d

            # Check if d is a descent direction
            if torch.dot(d, g) <= 0:
                print("Warning: d is not a descent direction")

            if self.line_search_fn == 'armijo':
                x_init = self._clone_param()

                def obj_func(x, t, dx):
                    self._add_grad(t, dx)
                    loss = float(closure()[0])
                    self._set_param(x)
                    return loss

                # Use -d for convention
                t = _armijo(obj_func, x_init, g, -d, group['lr'])
            else:
                t = group['lr']

            self.state[group_idx]['t'] = t

            # update parameters
            ls = 0
            for p in group['params']:
                np = torch.numel(p)
                dp = d[ls:ls+np].view(p.shape)
                ls += np
                if p.grad is None:
                    continue
                p.data.add_(-dp, alpha=t)

        self.n_iters += 1

        return loss, g

    def update_preconditioner(self, grad_tuple):
        gradsH = torch.cat([gradient.view(-1)
                           for gradient in grad_tuple if gradient is not None])

        p = gradsH.shape[0]
        # Generate test matrix (NOTE: This is transposed test matrix)
        Phi = torch.randn(
            (self.rank, p), device=self._params_list[0].device) / (p ** 0.5)
        Phi = torch.linalg.qr(Phi.t(), mode='reduced')[0].t()

        Y = self._hvp_vmap(gradsH, self._params_list)(Phi)

        # Calculate shift
        shift = torch.finfo(Y.dtype).eps
        Y_shifted = Y + shift * Phi
        # Calculate Phi^T * H * Phi (w/ shift) for Cholesky
        choleskytarget = torch.mm(Y_shifted, Phi.t())
        # Perform Cholesky, if fails, do eigendecomposition
        # The new shift is the abs of smallest eigenvalue (negative) plus the original shift
        try:
            C = torch.linalg.cholesky(choleskytarget)
        except:
            # eigendecomposition, eigenvalues and eigenvector matrix
            eigs, eigvectors = torch.linalg.eigh(choleskytarget)
            shift = shift + torch.abs(torch.min(eigs))
            # add shift to eigenvalues
            eigs = eigs + shift
            # put back the matrix for Cholesky by eigenvector * eigenvalues after shift * eigenvector^T
            C = torch.linalg.cholesky(
                torch.mm(eigvectors, torch.mm(torch.diag(eigs), eigvectors.T)))

        try:
            B = torch.linalg.solve_triangular(
                C, Y_shifted, upper=False, left=True)
        # temporary fix for issue @ https://github.com/pytorch/pytorch/issues/97211
        except:
            B = torch.linalg.solve_triangular(C.to('cpu'), Y_shifted.to(
                'cpu'), upper=False, left=True).to(C.device)
        # B = V * S * U^T b/c we have been using transposed sketch
        _, S, UT = torch.linalg.svd(B, full_matrices=False)
        self.U = UT.t()
        self.S = torch.max(torch.square(S) - shift, torch.tensor(0.0))

        self.rho = self.S[-1]

        if self.verbose:
            print(f'Approximate eigenvalues = {self.S}')

    def _hvp_vmap(self, grad_params, params):
        return vmap(lambda v: self._hvp(grad_params, params, v), in_dims=0, chunk_size=self.chunk_size)

    def _hvp(self, grad_params, params, v):
        Hv = torch.autograd.grad(grad_params, params, grad_outputs=v,
                                 retain_graph=True)
        Hv = tuple(Hvi.detach() for Hvi in Hv)
        return torch.cat([Hvi.reshape(-1) for Hvi in Hv])

    def _numel(self):
        if self._numel_cache is None:
            self._numel_cache = reduce(
                lambda total, p: total + p.numel(), self._params, 0)
        return self._numel_cache

    def _add_grad(self, step_size, update):
        offset = 0
        for p in self._params:
            numel = p.numel()
            # Avoid in-place operation by creating a new tensor
            p.data = p.data.add(
                update[offset:offset + numel].view_as(p), alpha=step_size)
            offset += numel
        assert offset == self._numel()

    def _clone_param(self):
        return [p.clone(memory_format=torch.contiguous_format) for p in self._params]

    def _set_param(self, params_data):
        for p, pdata in zip(self._params, params_data):
            # Replace the .data attribute of the tensor
            p.data = pdata.data

# %%
class LSQ(torch.nn.Module):
    def __init__(self, n_features):
        super(LSQ, self).__init__()
        self.w = torch.nn.Linear(n_features, 1, bias=False)

    def forward(self, x):
        return self.w(x)

# %%
# define experiment parameters
n_train = 5000
n_test = 500
n_features = 100
n_iters = 50

weight = np.random.normal(size=n_features)

# Xtrain = np.random.normal(size = (n_train, n_features))
# ytrain = (Xtrain @ weight)[: , np.newaxis]

# Xtest = np.sort(np.random.normal(size = (n_test, n_features)))
# ytest = (Xtest @ weight)[: , np.newaxis]

# Create a vector with polynomial decay starting at 1
decay = (np.arange(n_features) + 1) ** (-2.0)
decay = np.diag(decay)
U = ortho_group.rvs(n_train)[:, :n_features]
VT = ortho_group.rvs(n_features)
X = U @ decay @ VT

Xtrain = X[:n_train]
ytrain = (Xtrain @ weight)[:, np.newaxis]

# Xtest = X[n_train:]
# ytest = (Xtest @ weight)[: , np.newaxis]

print(f'True Hessian: {Xtrain.T @ Xtrain / n_train}')
# Out:
# True Hessian: [[5.87207932e-08 5.30202325e-07 3.84452423e-08 ... 1.77979336e-07
#   5.41539004e-07 9.73623657e-08]
#  [5.30202325e-07 6.54229435e-06 3.50059491e-07 ... 2.13488754e-06
#   6.16464522e-06 1.13735742e-06]
#  [3.84452423e-08 3.50059491e-07 8.98778386e-08 ... 1.02080514e-07
#   1.62413930e-07 1.57564297e-07]
#  ...
#  [1.77979336e-07 2.13488754e-06 1.02080514e-07 ... 7.74132079e-07
#   2.26517543e-06 3.62492561e-07]
#  [5.41539004e-07 6.16464522e-06 1.62413930e-07 ... 2.26517543e-06
#   7.11691785e-06 8.17371842e-07]
#  [9.73623657e-08 1.13735742e-06 1.57564297e-07 ... 3.62492561e-07
#   8.17371842e-07 3.56961183e-07]]

# %%
model = LSQ(n_features)

# specify optimizer
optimizer = NysNewtonCG(model.parameters(), lr=1.0,
                      rank=10, mu=0, cg_tol=1e-16, cg_max_iters=3000, line_search_fn='armijo')
precond_update_freq = 20

loss_hist = []
step_size_hist = []

Xt = torch.tensor(Xtrain, dtype=torch.float)
yt = torch.tensor(ytrain, dtype=torch.float)

torch.nn.init.zeros_(model.w.weight)

loss_function = nn.MSELoss()

for i in range(n_iters):
    model.train()

    # Update preconditioner for PCG
    if i % precond_update_freq == 0:
        optimizer.zero_grad()
        output = model(Xt)
        loss = loss_function(output, yt)
        grad_tuple = torch.autograd.grad(
            loss, model.parameters(), create_graph=True)
        optimizer.update_preconditioner(grad_tuple)

    # Take a step
    def closure():
        optimizer.zero_grad()
        output = model(Xt)
        loss = loss_function(output, yt)
        grad_tuple = torch.autograd.grad(
            loss, model.parameters(), create_graph=True)
        return loss, grad_tuple

    optimizer.step(closure)

    model.eval()
    output = model(Xt)
    loss = loss_function(output, yt).item()
    loss_hist.append(loss)

    step_size_hist.append(optimizer.state_dict()['state'][0]['t'])

    if i % 1 == 0:
        print(f'Iteration {i} | Loss: {loss}')
        # print(optimizer.U @ torch.diag(optimizer.S) @ optimizer.U.t())
        # print(optimizer.S)
        # print(optimizer.rho)
# Out:
# PCG iteration 0 complete. Residual norm = 0.00026859284844249487
# PCG iteration 100 complete. Residual norm = 1.6308203498738294e-07
# PCG iteration 200 complete. Residual norm = 1.747113032024572e-07
# PCG iteration 300 complete. Residual norm = 3.3161501988843156e-08
# PCG iteration 400 complete. Residual norm = 9.619902208157782e-09
# PCG iteration 500 complete. Residual norm = 1.5657322549600394e-08
# PCG iteration 600 complete. Residual norm = 1.5950593734714857e-08
# PCG iteration 700 complete. Residual norm = 1.1943350308740719e-08
# PCG iteration 800 complete. Residual norm = 4.711823820002792e-09
# PCG iteration 900 complete. Residual norm = 5.792965551698614e-10
# PCG iteration 1000 complete. Residual norm = 2.5352251409316295e-09
# PCG iteration 1100 complete. Residual norm = 1.1603052962882998e-09
# PCG iteration 1200 complete. Residual norm = 3.487970579030275e-09
# PCG iteration 1300 complete. Residual norm = 3.8693689918822827e-10
# PCG iteration 1400 complete. Residual norm = 1.1918374065444937e-09
# PCG iteration 1500 complete. Residual norm = 2.864116166456654e-10
# PCG iteration 1600 complete. Residual norm = 2.071150334570504e-10
# PCG iteration 1700 complete. Residual norm = 2.794603784495031e-11
# PCG iteration 1800 complete. Residual norm = 1.5882109516418552e-10
# PCG iteration 1900 complete. Residual norm = 7.635306970010802e-11
# PCG iteration 2000 complete. Residual norm = 1.346284368708428e-11
# PCG iteration 2100 complete. Residual norm = 1.627873877363406e-11
# PCG iteration 2200 complete. Residual norm = 9.700271835777485e-11
# PCG iteration 2300 complete. Residual norm = 5.161654784147096e-11
# PCG iteration 2400 complete. Residual norm = 1.0820804322020372e-11
# PCG iteration 2500 complete. Residual norm = 9.735339270844356e-12
# PCG iteration 2600 complete. Residual norm = 7.367644905623139e-13
# PCG iteration 2700 complete. Residual norm = 7.581309440906486e-14
# PCG iteration 2800 complete. Residual norm = 3.3645457839064086e-13
# PCG iteration 2900 complete. Residual norm = 5.682898203125501e-15
# Warning: PCG did not converge to tolerance. Tolerance was 1e-16 but norm of residual is 2.2533295623286195e-14
# Iteration 0 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 8.164436904323225e-10
# PCG iteration 100 complete. Residual norm = 1.4338540077485362e-10
# PCG iteration 200 complete. Residual norm = 3.5602334969020433e-10
# PCG iteration 300 complete. Residual norm = 1.3427604861337983e-10
# PCG iteration 400 complete. Residual norm = 6.355430071103285e-11
# PCG iteration 500 complete. Residual norm = 2.4478615315293162e-11
# PCG iteration 600 complete. Residual norm = 5.039281492091874e-11
# PCG iteration 700 complete. Residual norm = 4.525904997998431e-11
# PCG iteration 800 complete. Residual norm = 2.1836251556939246e-11
# PCG iteration 900 complete. Residual norm = 1.513103531358695e-11
# PCG iteration 1000 complete. Residual norm = 9.907018781729615e-12
# PCG iteration 1100 complete. Residual norm = 4.5882346533243634e-11
# PCG iteration 1200 complete. Residual norm = 3.3247636414823756e-12
# PCG iteration 1300 complete. Residual norm = 1.0834202458787079e-11
# PCG iteration 1400 complete. Residual norm = 9.054848884582078e-12
# PCG iteration 1500 complete. Residual norm = 2.969055340126814e-12
# PCG iteration 1600 complete. Residual norm = 2.855252492772742e-12
# PCG iteration 1700 complete. Residual norm = 3.6210552785409522e-12
# PCG iteration 1800 complete. Residual norm = 9.572983681802039e-13
# PCG iteration 1900 complete. Residual norm = 1.7921155824520557e-13
# PCG iteration 2000 complete. Residual norm = 1.5145678222867887e-13
# PCG iteration 2100 complete. Residual norm = 2.8420865785588542e-14
# PCG iteration 2200 complete. Residual norm = 2.4926261955101475e-14
# PCG iteration 2300 complete. Residual norm = 4.21376495707889e-14
# PCG iteration 2400 complete. Residual norm = 4.991243624462814e-14
# PCG iteration 2500 complete. Residual norm = 1.8084862813972638e-15
# PCG iteration 2600 complete. Residual norm = 2.407259377525486e-15
# PCG iteration 2700 complete. Residual norm = 3.303235794296271e-15
# PCG iteration 2800 complete. Residual norm = 4.417927976509378e-16
# PCG iteration 2900 complete. Residual norm = 4.660245573873112e-16
# Iteration 1 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 6.097753968425934e-10
# PCG iteration 100 complete. Residual norm = 4.878096593330383e-09
# PCG iteration 200 complete. Residual norm = 6.969896326758374e-10
# PCG iteration 300 complete. Residual norm = 6.516671230416549e-11
# PCG iteration 400 complete. Residual norm = 2.1206296441089734e-10
# PCG iteration 500 complete. Residual norm = 1.236740015952975e-10
# PCG iteration 600 complete. Residual norm = 4.155066291033904e-10
# PCG iteration 700 complete. Residual norm = 1.6190358775869385e-10
# PCG iteration 800 complete. Residual norm = 7.212822006330555e-11
# PCG iteration 900 complete. Residual norm = 3.312921811882141e-11
# PCG iteration 1000 complete. Residual norm = 3.3268703764077756e-11
# PCG iteration 1100 complete. Residual norm = 1.9260398831377756e-11
# PCG iteration 1200 complete. Residual norm = 3.8432645954600275e-11
# PCG iteration 1300 complete. Residual norm = 1.680033889783772e-11
# PCG iteration 1400 complete. Residual norm = 6.14227375558829e-12
# PCG iteration 1500 complete. Residual norm = 1.1389637497027927e-11
# PCG iteration 1600 complete. Residual norm = 6.969917264870729e-12
# PCG iteration 1700 complete. Residual norm = 3.5952833592201028e-12
# PCG iteration 1800 complete. Residual norm = 1.4238554996506836e-12
# PCG iteration 1900 complete. Residual norm = 7.516519416432554e-13
# PCG iteration 2000 complete. Residual norm = 3.838918318974614e-14
# PCG iteration 2100 complete. Residual norm = 1.533920153439297e-13
# PCG iteration 2200 complete. Residual norm = 2.962300814802338e-13
# PCG iteration 2300 complete. Residual norm = 6.195273515117311e-14
# PCG iteration 2400 complete. Residual norm = 5.2108474192470375e-14
# PCG iteration 2500 complete. Residual norm = 8.859461490709312e-15
# PCG iteration 2600 complete. Residual norm = 1.5213164895314015e-15
# PCG iteration 2700 complete. Residual norm = 1.255910044574936e-15
# Iteration 2 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 2.923295217005517e-10
# PCG iteration 100 complete. Residual norm = 1.4813166249183496e-09
# PCG iteration 200 complete. Residual norm = 1.2895331469309212e-09
# PCG iteration 300 complete. Residual norm = 4.38977770800264e-10
# PCG iteration 400 complete. Residual norm = 5.538816627570498e-10
# PCG iteration 500 complete. Residual norm = 3.159809636166244e-10
# PCG iteration 600 complete. Residual norm = 3.322188357746114e-10
# PCG iteration 700 complete. Residual norm = 9.130006473068164e-11
# PCG iteration 800 complete. Residual norm = 2.8970832677277514e-11
# PCG iteration 900 complete. Residual norm = 5.638026503995697e-11
# PCG iteration 1000 complete. Residual norm = 2.758896722188098e-10
# PCG iteration 1100 complete. Residual norm = 2.6116419790667145e-11
# PCG iteration 1200 complete. Residual norm = 3.0311614329647796e-11
# PCG iteration 1300 complete. Residual norm = 1.7780584947099665e-12
# PCG iteration 1400 complete. Residual norm = 2.912135593433063e-12
# PCG iteration 1500 complete. Residual norm = 2.112124494399459e-12
# PCG iteration 1600 complete. Residual norm = 2.106753139996531e-12
# PCG iteration 1700 complete. Residual norm = 3.5337084278684594e-13
# PCG iteration 1800 complete. Residual norm = 5.339842066784395e-13
# PCG iteration 1900 complete. Residual norm = 1.9506493859414165e-13
# PCG iteration 2000 complete. Residual norm = 2.3700792305299256e-13
# PCG iteration 2100 complete. Residual norm = 4.910525450347626e-14
# PCG iteration 2200 complete. Residual norm = 5.34460213783808e-15
# PCG iteration 2300 complete. Residual norm = 8.820676699087485e-15
# PCG iteration 2400 complete. Residual norm = 5.122486382145479e-15
# PCG iteration 2500 complete. Residual norm = 9.108059731497819e-15
# PCG iteration 2600 complete. Residual norm = 1.6489735873417496e-14
# PCG iteration 2700 complete. Residual norm = 1.0373125461078745e-15
# PCG iteration 2800 complete. Residual norm = 1.6048487082676933e-16
# PCG iteration 2900 complete. Residual norm = 8.086395695573994e-15
# Warning: PCG did not converge to tolerance. Tolerance was 1e-16 but norm of residual is 2.1293800547833456e-15
# Iteration 3 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 3.0417496299506297e-10
# PCG iteration 100 complete. Residual norm = 1.340930477766733e-09
# PCG iteration 200 complete. Residual norm = 2.0651358401124753e-10
# PCG iteration 300 complete. Residual norm = 5.652993073645973e-10
# PCG iteration 400 complete. Residual norm = 2.889976868925004e-10
# PCG iteration 500 complete. Residual norm = 1.4547753279803288e-10
# PCG iteration 600 complete. Residual norm = 2.954041178337974e-10
# PCG iteration 700 complete. Residual norm = 3.419126370918235e-10
# PCG iteration 800 complete. Residual norm = 9.542585471811194e-11
# PCG iteration 900 complete. Residual norm = 1.5456504132149718e-10
# PCG iteration 1000 complete. Residual norm = 3.09174734425266e-11
# PCG iteration 1100 complete. Residual norm = 4.363746169966376e-11
# PCG iteration 1200 complete. Residual norm = 1.6702764171760975e-11
# PCG iteration 1300 complete. Residual norm = 2.5328661043544365e-11
# PCG iteration 1400 complete. Residual norm = 3.2041778084967998e-12
# PCG iteration 1500 complete. Residual norm = 4.694167689105189e-13
# PCG iteration 1600 complete. Residual norm = 2.5953373564840954e-12
# PCG iteration 1700 complete. Residual norm = 5.61077876867766e-13
# PCG iteration 1800 complete. Residual norm = 7.176316290345708e-13
# PCG iteration 1900 complete. Residual norm = 1.3197705732090337e-13
# PCG iteration 2000 complete. Residual norm = 8.407098124217291e-14
# PCG iteration 2100 complete. Residual norm = 1.5132045396988418e-14
# PCG iteration 2200 complete. Residual norm = 3.3763847972915e-14
# PCG iteration 2300 complete. Residual norm = 1.68942940556192e-14
# PCG iteration 2400 complete. Residual norm = 1.5946996124332515e-14
# PCG iteration 2500 complete. Residual norm = 1.669359319865732e-15
# PCG iteration 2600 complete. Residual norm = 1.1306614002468108e-15
# PCG iteration 2700 complete. Residual norm = 8.366025306022517e-16
# PCG iteration 2800 complete. Residual norm = 5.571998296923864e-15
# PCG iteration 2900 complete. Residual norm = 1.3106796184608727e-15
# Warning: PCG did not converge to tolerance. Tolerance was 1e-16 but norm of residual is 9.988852023897887e-16
# Iteration 4 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 4.385188323574596e-10
# PCG iteration 100 complete. Residual norm = 1.8581498562042498e-09
# PCG iteration 200 complete. Residual norm = 1.9933752426481988e-09
# PCG iteration 300 complete. Residual norm = 1.2735916765649336e-09
# PCG iteration 400 complete. Residual norm = 3.1179685500148935e-09
# PCG iteration 500 complete. Residual norm = 2.441444268974635e-10
# PCG iteration 600 complete. Residual norm = 1.570094332326022e-10
# PCG iteration 700 complete. Residual norm = 3.670884429762822e-11
# PCG iteration 800 complete. Residual norm = 8.511172322478444e-11
# PCG iteration 900 complete. Residual norm = 1.449784129553544e-11
# PCG iteration 1000 complete. Residual norm = 3.1231767172457126e-11
# PCG iteration 1100 complete. Residual norm = 2.0883328052945238e-11
# PCG iteration 1200 complete. Residual norm = 4.9715780103820606e-11
# PCG iteration 1300 complete. Residual norm = 9.271980752623143e-12
# PCG iteration 1400 complete. Residual norm = 1.6535033975709212e-12
# PCG iteration 1500 complete. Residual norm = 4.181493259286517e-12
# PCG iteration 1600 complete. Residual norm = 4.85741091446612e-12
# PCG iteration 1700 complete. Residual norm = 4.064783232227143e-12
# PCG iteration 1800 complete. Residual norm = 3.817585570581317e-12
# PCG iteration 1900 complete. Residual norm = 8.287139420873335e-13
# PCG iteration 2000 complete. Residual norm = 3.0098642220081906e-13
# PCG iteration 2100 complete. Residual norm = 3.030271075298713e-13
# PCG iteration 2200 complete. Residual norm = 1.944446665312627e-13
# PCG iteration 2300 complete. Residual norm = 6.4056286418537594e-15
# PCG iteration 2400 complete. Residual norm = 3.1099234786783475e-14
# PCG iteration 2500 complete. Residual norm = 7.101593686481729e-15
# PCG iteration 2600 complete. Residual norm = 4.0734038897190326e-15
# PCG iteration 2700 complete. Residual norm = 2.435705284993127e-15
# PCG iteration 2800 complete. Residual norm = 9.257083320105951e-16
# Iteration 5 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 3.345382859620827e-10
# PCG iteration 100 complete. Residual norm = 1.965366203116048e-10
# PCG iteration 200 complete. Residual norm = 9.078438556464619e-10
# PCG iteration 300 complete. Residual norm = 1.4780967561023317e-09
# PCG iteration 400 complete. Residual norm = 1.3197681836274455e-10
# PCG iteration 500 complete. Residual norm = 5.575495065635039e-10
# PCG iteration 600 complete. Residual norm = 1.0127864519260399e-10
# PCG iteration 700 complete. Residual norm = 4.107572268430282e-11
# PCG iteration 800 complete. Residual norm = 1.765583512725044e-10
# PCG iteration 900 complete. Residual norm = 3.211543531111971e-10
# PCG iteration 1000 complete. Residual norm = 1.5336601433268982e-10
# PCG iteration 1100 complete. Residual norm = 1.7943597996339378e-11
# PCG iteration 1200 complete. Residual norm = 2.923986400227285e-11
# PCG iteration 1300 complete. Residual norm = 7.938722595968173e-12
# PCG iteration 1400 complete. Residual norm = 4.852195034654727e-12
# PCG iteration 1500 complete. Residual norm = 3.822941529313395e-12
# PCG iteration 1600 complete. Residual norm = 8.239892275441196e-12
# PCG iteration 1700 complete. Residual norm = 4.605994405326719e-13
# PCG iteration 1800 complete. Residual norm = 1.2261896142548578e-12
# PCG iteration 1900 complete. Residual norm = 1.3206149498609654e-12
# PCG iteration 2000 complete. Residual norm = 9.96295168760597e-13
# PCG iteration 2100 complete. Residual norm = 6.189891806583636e-13
# PCG iteration 2200 complete. Residual norm = 8.60174290736454e-14
# PCG iteration 2300 complete. Residual norm = 1.0983537891045073e-13
# PCG iteration 2400 complete. Residual norm = 3.135608228144529e-14
# PCG iteration 2500 complete. Residual norm = 1.4106633240272993e-14
# PCG iteration 2600 complete. Residual norm = 5.4072889286820025e-15
# PCG iteration 2700 complete. Residual norm = 1.9956026357093168e-15
# PCG iteration 2800 complete. Residual norm = 3.651650515171592e-15
# PCG iteration 2900 complete. Residual norm = 5.218039533650526e-16
# Warning: PCG did not converge to tolerance. Tolerance was 1e-16 but norm of residual is 1.2704462946201223e-15
# Iteration 6 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 4.351637938881936e-10
# PCG iteration 100 complete. Residual norm = 2.268587317999504e-09
# PCG iteration 200 complete. Residual norm = 3.2699287721982273e-10
# PCG iteration 300 complete. Residual norm = 2.389937581170898e-09
# PCG iteration 400 complete. Residual norm = 5.917618617345966e-10
# PCG iteration 500 complete. Residual norm = 4.6111420237693324e-10
# PCG iteration 600 complete. Residual norm = 3.3556969702974726e-11
# PCG iteration 700 complete. Residual norm = 3.3929432180501706e-11
# PCG iteration 800 complete. Residual norm = 4.196274230872099e-11
# PCG iteration 900 complete. Residual norm = 1.3926925584994976e-11
# PCG iteration 1000 complete. Residual norm = 1.5409222509088494e-10
# PCG iteration 1100 complete. Residual norm = 2.9557509217958966e-11
# PCG iteration 1200 complete. Residual norm = 8.2969273812461e-12
# PCG iteration 1300 complete. Residual norm = 6.1665516443154544e-12
# PCG iteration 1400 complete. Residual norm = 4.765021276859072e-12
# PCG iteration 1500 complete. Residual norm = 9.878891975290127e-12
# PCG iteration 1600 complete. Residual norm = 5.0012303326463226e-12
# PCG iteration 1700 complete. Residual norm = 1.4307475560207394e-12
# PCG iteration 1800 complete. Residual norm = 1.7130486482455631e-13
# PCG iteration 1900 complete. Residual norm = 5.935022980886606e-13
# PCG iteration 2000 complete. Residual norm = 1.246900396519382e-13
# PCG iteration 2100 complete. Residual norm = 2.1257098186712453e-14
# PCG iteration 2200 complete. Residual norm = 3.92541368130655e-15
# PCG iteration 2300 complete. Residual norm = 2.7535738378564427e-14
# PCG iteration 2400 complete. Residual norm = 1.711689431415763e-14
# PCG iteration 2500 complete. Residual norm = 4.448515395025915e-15
# PCG iteration 2600 complete. Residual norm = 5.102851311395177e-15
# PCG iteration 2700 complete. Residual norm = 2.0184060331988234e-15
# PCG iteration 2800 complete. Residual norm = 1.0172630644881284e-15
# PCG iteration 2900 complete. Residual norm = 9.240678409500004e-16
# Warning: PCG did not converge to tolerance. Tolerance was 1e-16 but norm of residual is 1.669361119810745e-15
# Iteration 7 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 8.425500297448707e-10
# PCG iteration 100 complete. Residual norm = 1.994224119172827e-09
# PCG iteration 200 complete. Residual norm = 2.4508486906604787e-10
# PCG iteration 300 complete. Residual norm = 1.8920434108338213e-09
# PCG iteration 400 complete. Residual norm = 5.67957902930516e-10
# PCG iteration 500 complete. Residual norm = 4.046835089255296e-10
# PCG iteration 600 complete. Residual norm = 4.2681230771890455e-10
# PCG iteration 700 complete. Residual norm = 1.9890601665739638e-10
# PCG iteration 800 complete. Residual norm = 1.266918098208336e-10
# PCG iteration 900 complete. Residual norm = 1.4772298662091288e-10
# PCG iteration 1000 complete. Residual norm = 8.701480508355175e-11
# PCG iteration 1100 complete. Residual norm = 7.987689676358656e-11
# PCG iteration 1200 complete. Residual norm = 2.975367868751633e-11
# PCG iteration 1300 complete. Residual norm = 3.101304976715902e-11
# PCG iteration 1400 complete. Residual norm = 4.988634505487255e-11
# PCG iteration 1500 complete. Residual norm = 6.071943642327327e-11
# PCG iteration 1600 complete. Residual norm = 5.2507516563882195e-12
# PCG iteration 1700 complete. Residual norm = 8.552055548102788e-13
# PCG iteration 1800 complete. Residual norm = 3.866576113106812e-13
# PCG iteration 1900 complete. Residual norm = 3.1653537213224836e-13
# PCG iteration 2000 complete. Residual norm = 1.9437419339005113e-13
# PCG iteration 2100 complete. Residual norm = 1.5461359948419628e-13
# PCG iteration 2200 complete. Residual norm = 1.6874187865143636e-13
# PCG iteration 2300 complete. Residual norm = 9.860243453977888e-14
# PCG iteration 2400 complete. Residual norm = 9.645871442895675e-15
# PCG iteration 2500 complete. Residual norm = 2.1251952885074357e-15
# PCG iteration 2600 complete. Residual norm = 5.0419911471020085e-15
# PCG iteration 2700 complete. Residual norm = 3.4999915953063147e-15
# PCG iteration 2800 complete. Residual norm = 2.5883605273626124e-15
# Iteration 8 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 2.799661613650528e-10
# PCG iteration 100 complete. Residual norm = 3.5135488962723116e-10
# PCG iteration 200 complete. Residual norm = 8.094875325603823e-10
# PCG iteration 300 complete. Residual norm = 9.731221384257083e-10
# PCG iteration 400 complete. Residual norm = 1.4184937668915154e-09
# PCG iteration 500 complete. Residual norm = 8.731276118778553e-11
# PCG iteration 600 complete. Residual norm = 4.347185389441677e-10
# PCG iteration 700 complete. Residual norm = 2.8518229444607357e-10
# PCG iteration 800 complete. Residual norm = 1.874175120653021e-10
# PCG iteration 900 complete. Residual norm = 1.1608437301691144e-11
# PCG iteration 1000 complete. Residual norm = 7.145546654374613e-11
# PCG iteration 1100 complete. Residual norm = 1.4693324681958053e-11
# PCG iteration 1200 complete. Residual norm = 1.6939445722854996e-12
# PCG iteration 1300 complete. Residual norm = 1.3124504738212805e-12
# PCG iteration 1400 complete. Residual norm = 7.282739949293626e-13
# PCG iteration 1500 complete. Residual norm = 2.016834832821446e-12
# PCG iteration 1600 complete. Residual norm = 1.1185228090959676e-12
# PCG iteration 1700 complete. Residual norm = 8.862729885920906e-13
# PCG iteration 1800 complete. Residual norm = 2.88247534565092e-13
# PCG iteration 1900 complete. Residual norm = 2.7044973248749327e-13
# PCG iteration 2000 complete. Residual norm = 6.83209863466469e-14
# PCG iteration 2100 complete. Residual norm = 3.396187682209312e-13
# PCG iteration 2200 complete. Residual norm = 9.925671666955599e-14
# PCG iteration 2300 complete. Residual norm = 8.892147814517498e-14
# PCG iteration 2400 complete. Residual norm = 7.348819733895683e-15
# PCG iteration 2500 complete. Residual norm = 5.057798475963668e-15
# PCG iteration 2600 complete. Residual norm = 3.587198931182065e-15
# PCG iteration 2700 complete. Residual norm = 1.105775995772953e-15
# Iteration 9 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 5.162483218690284e-10
# PCG iteration 100 complete. Residual norm = 4.50224968417956e-09
# PCG iteration 200 complete. Residual norm = 1.0451195464611374e-09
# PCG iteration 300 complete. Residual norm = 1.0573236730593294e-09
# PCG iteration 400 complete. Residual norm = 1.3188304615052715e-10
# PCG iteration 500 complete. Residual norm = 9.213432239363328e-10
# PCG iteration 600 complete. Residual norm = 9.178468401982443e-11
# PCG iteration 700 complete. Residual norm = 9.639527370763901e-11
# PCG iteration 800 complete. Residual norm = 8.65208252265326e-11
# PCG iteration 900 complete. Residual norm = 1.6731858953900058e-10
# PCG iteration 1000 complete. Residual norm = 1.8770320020511377e-10
# PCG iteration 1100 complete. Residual norm = 2.3247067465481663e-11
# PCG iteration 1200 complete. Residual norm = 5.118799047826306e-12
# PCG iteration 1300 complete. Residual norm = 1.7579005959222904e-11
# PCG iteration 1400 complete. Residual norm = 9.00683607557573e-12
# PCG iteration 1500 complete. Residual norm = 3.1925934118604005e-11
# PCG iteration 1600 complete. Residual norm = 6.425222767031391e-12
# PCG iteration 1700 complete. Residual norm = 5.26561433344952e-12
# PCG iteration 1800 complete. Residual norm = 2.848742075567401e-12
# PCG iteration 1900 complete. Residual norm = 1.981880588461382e-12
# PCG iteration 2000 complete. Residual norm = 1.6538468728191646e-12
# PCG iteration 2100 complete. Residual norm = 1.0292391938726553e-12
# PCG iteration 2200 complete. Residual norm = 4.3894499580227064e-13
# PCG iteration 2300 complete. Residual norm = 2.1023626090889425e-13
# PCG iteration 2400 complete. Residual norm = 2.296665461976044e-14
# PCG iteration 2500 complete. Residual norm = 1.663243551404143e-14
# PCG iteration 2600 complete. Residual norm = 1.7758264908961509e-15
# PCG iteration 2700 complete. Residual norm = 1.1775483796464805e-15
# PCG iteration 2800 complete. Residual norm = 5.94810570121848e-16
# PCG iteration 2900 complete. Residual norm = 3.1082104286579086e-16
# Warning: PCG did not converge to tolerance. Tolerance was 1e-16 but norm of residual is 2.3409998017100446e-15
# Iteration 10 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 3.4632766099385037e-10
# PCG iteration 100 complete. Residual norm = 1.0452287924067605e-09
# PCG iteration 200 complete. Residual norm = 1.7780712457948766e-09
# PCG iteration 300 complete. Residual norm = 4.195589986544235e-10
# PCG iteration 400 complete. Residual norm = 1.514280700831705e-09
# PCG iteration 500 complete. Residual norm = 1.178809688751059e-10
# PCG iteration 600 complete. Residual norm = 1.3292975054035594e-10
# PCG iteration 700 complete. Residual norm = 5.69573173347937e-11
# PCG iteration 800 complete. Residual norm = 4.1702346437189064e-11
# PCG iteration 900 complete. Residual norm = 1.146873290780448e-10
# PCG iteration 1000 complete. Residual norm = 5.89018556151899e-11
# PCG iteration 1100 complete. Residual norm = 9.401581596568676e-11
# PCG iteration 1200 complete. Residual norm = 8.153687794387743e-12
# PCG iteration 1300 complete. Residual norm = 3.939855039436502e-11
# PCG iteration 1400 complete. Residual norm = 1.3845708433934956e-12
# PCG iteration 1500 complete. Residual norm = 1.8116548842692093e-12
# PCG iteration 1600 complete. Residual norm = 6.734499026148089e-13
# PCG iteration 1700 complete. Residual norm = 5.83377584521122e-13
# PCG iteration 1800 complete. Residual norm = 4.263235543668781e-13
# PCG iteration 1900 complete. Residual norm = 6.139191802492783e-13
# PCG iteration 2000 complete. Residual norm = 3.1248370861367003e-13
# PCG iteration 2100 complete. Residual norm = 1.9246560454318912e-13
# PCG iteration 2200 complete. Residual norm = 3.6288880971360737e-13
# PCG iteration 2300 complete. Residual norm = 3.946471513298355e-14
# PCG iteration 2400 complete. Residual norm = 5.756785564740852e-14
# PCG iteration 2500 complete. Residual norm = 3.159505738092004e-14
# PCG iteration 2600 complete. Residual norm = 3.4658559557737296e-15
# PCG iteration 2700 complete. Residual norm = 7.079031799261308e-16
# PCG iteration 2800 complete. Residual norm = 1.0636402359326695e-15
# Iteration 11 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 5.094701882590869e-10
# PCG iteration 100 complete. Residual norm = 1.1423032519886078e-09
# PCG iteration 200 complete. Residual norm = 1.0013098128425213e-09
# PCG iteration 300 complete. Residual norm = 3.683438831725283e-10
# PCG iteration 400 complete. Residual norm = 2.1182708365152791e-10
# PCG iteration 500 complete. Residual norm = 1.209866928864045e-10
# PCG iteration 600 complete. Residual norm = 9.504464576481908e-11
# PCG iteration 700 complete. Residual norm = 6.153926812579869e-10
# PCG iteration 800 complete. Residual norm = 2.550128164191534e-10
# PCG iteration 900 complete. Residual norm = 3.8379140143707247e-11
# PCG iteration 1000 complete. Residual norm = 1.8426106473956594e-10
# PCG iteration 1100 complete. Residual norm = 3.210747293036498e-11
# PCG iteration 1200 complete. Residual norm = 4.5890194422248953e-11
# PCG iteration 1300 complete. Residual norm = 1.9786405153210396e-11
# PCG iteration 1400 complete. Residual norm = 1.4069768787539072e-11
# PCG iteration 1500 complete. Residual norm = 4.159768016154253e-12
# PCG iteration 1600 complete. Residual norm = 2.4929546274532477e-12
# PCG iteration 1700 complete. Residual norm = 1.6006598173648467e-12
# PCG iteration 1800 complete. Residual norm = 3.802470057573393e-12
# PCG iteration 1900 complete. Residual norm = 9.317915362905271e-13
# PCG iteration 2000 complete. Residual norm = 3.306540696627891e-13
# PCG iteration 2100 complete. Residual norm = 2.0419598087059732e-13
# PCG iteration 2200 complete. Residual norm = 7.33046232764302e-14
# PCG iteration 2300 complete. Residual norm = 1.9093759098766025e-14
# PCG iteration 2400 complete. Residual norm = 6.161977920510165e-15
# PCG iteration 2500 complete. Residual norm = 2.4286130781257667e-15
# PCG iteration 2600 complete. Residual norm = 7.681411455799821e-16
# PCG iteration 2700 complete. Residual norm = 1.565141444826747e-15
# PCG iteration 2800 complete. Residual norm = 1.3171184452885447e-15
# PCG iteration 2900 complete. Residual norm = 4.237865500823822e-15
# Warning: PCG did not converge to tolerance. Tolerance was 1e-16 but norm of residual is 1.3486869397162388e-15
# Iteration 12 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 6.105480565565813e-10
# PCG iteration 100 complete. Residual norm = 1.5670756914332173e-09
# PCG iteration 200 complete. Residual norm = 6.674796826366958e-10
# PCG iteration 300 complete. Residual norm = 2.753212380302017e-10
# PCG iteration 400 complete. Residual norm = 6.790151774183073e-10
# PCG iteration 500 complete. Residual norm = 1.8492453401908193e-10
# PCG iteration 600 complete. Residual norm = 1.0164828007086513e-10
# PCG iteration 700 complete. Residual norm = 3.450433827545396e-10
# PCG iteration 800 complete. Residual norm = 1.2290185535945852e-10
# PCG iteration 900 complete. Residual norm = 1.5467932490409453e-11
# PCG iteration 1000 complete. Residual norm = 5.921729773206152e-11
# PCG iteration 1100 complete. Residual norm = 5.114310364096042e-11
# PCG iteration 1200 complete. Residual norm = 7.852062750002275e-11
# PCG iteration 1300 complete. Residual norm = 2.5185731972188208e-11
# PCG iteration 1400 complete. Residual norm = 1.7186006090463835e-11
# PCG iteration 1500 complete. Residual norm = 1.8805408619204655e-11
# PCG iteration 1600 complete. Residual norm = 4.799009280243016e-12
# PCG iteration 1700 complete. Residual norm = 4.23032745985874e-12
# PCG iteration 1800 complete. Residual norm = 1.6016211794311896e-12
# PCG iteration 1900 complete. Residual norm = 2.9804755668702554e-13
# PCG iteration 2000 complete. Residual norm = 2.425913202958041e-12
# PCG iteration 2100 complete. Residual norm = 9.291651920529526e-14
# PCG iteration 2200 complete. Residual norm = 3.254153945007193e-13
# PCG iteration 2300 complete. Residual norm = 8.545996619787125e-14
# PCG iteration 2400 complete. Residual norm = 5.421201953060423e-14
# PCG iteration 2500 complete. Residual norm = 1.5896699307924554e-14
# PCG iteration 2600 complete. Residual norm = 1.3465277468545692e-15
# PCG iteration 2700 complete. Residual norm = 1.0078559165759221e-15
# PCG iteration 2800 complete. Residual norm = 5.965225295873674e-16
# PCG iteration 2900 complete. Residual norm = 5.41869634489915e-15
# Warning: PCG did not converge to tolerance. Tolerance was 1e-16 but norm of residual is 7.925845576740506e-16
# Iteration 13 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 8.974259668725892e-10
# PCG iteration 100 complete. Residual norm = 1.5681084208907237e-09
# PCG iteration 200 complete. Residual norm = 8.949476160147185e-10
# PCG iteration 300 complete. Residual norm = 1.301496826977555e-10
# PCG iteration 400 complete. Residual norm = 2.748095639937276e-10
# PCG iteration 500 complete. Residual norm = 4.3668427207599336e-10
# PCG iteration 600 complete. Residual norm = 1.7298884547045645e-10
# PCG iteration 700 complete. Residual norm = 1.247672243298581e-10
# PCG iteration 800 complete. Residual norm = 5.6030409478768917e-11
# PCG iteration 900 complete. Residual norm = 4.954755009056733e-11
# PCG iteration 1000 complete. Residual norm = 7.82159614853839e-11
# PCG iteration 1100 complete. Residual norm = 4.1753687313184074e-11
# PCG iteration 1200 complete. Residual norm = 2.1809415384765884e-11
# PCG iteration 1300 complete. Residual norm = 3.26885046808556e-12
# PCG iteration 1400 complete. Residual norm = 2.8770195861088643e-12
# PCG iteration 1500 complete. Residual norm = 4.3260625116892104e-12
# PCG iteration 1600 complete. Residual norm = 1.4417798552268657e-11
# PCG iteration 1700 complete. Residual norm = 5.025126582208772e-12
# PCG iteration 1800 complete. Residual norm = 5.966444352467626e-12
# PCG iteration 1900 complete. Residual norm = 1.241086660525026e-12
# PCG iteration 2000 complete. Residual norm = 3.940452564937802e-12
# PCG iteration 2100 complete. Residual norm = 3.2212107330467643e-13
# PCG iteration 2200 complete. Residual norm = 1.3100337871788104e-12
# PCG iteration 2300 complete. Residual norm = 8.448318135562474e-14
# PCG iteration 2400 complete. Residual norm = 1.1505598177755788e-13
# PCG iteration 2500 complete. Residual norm = 9.01136499133811e-15
# PCG iteration 2600 complete. Residual norm = 5.3939274074555395e-15
# PCG iteration 2700 complete. Residual norm = 1.395274704727291e-15
# PCG iteration 2800 complete. Residual norm = 1.7767195018505733e-16
# Iteration 14 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 5.713280404329169e-10
# PCG iteration 100 complete. Residual norm = 1.5110888096359076e-09
# PCG iteration 200 complete. Residual norm = 2.4576816137766855e-09
# PCG iteration 300 complete. Residual norm = 1.3923098229895459e-09
# PCG iteration 400 complete. Residual norm = 5.649378187477794e-10
# PCG iteration 500 complete. Residual norm = 4.580694989986256e-10
# PCG iteration 600 complete. Residual norm = 3.2455976795020547e-10
# PCG iteration 700 complete. Residual norm = 2.13175171959179e-10
# PCG iteration 800 complete. Residual norm = 8.712168486635363e-11
# PCG iteration 900 complete. Residual norm = 4.760774066636664e-11
# PCG iteration 1000 complete. Residual norm = 2.793729969585712e-10
# PCG iteration 1100 complete. Residual norm = 1.599387983164391e-11
# PCG iteration 1200 complete. Residual norm = 3.8882725164612886e-12
# PCG iteration 1300 complete. Residual norm = 2.8159315157427756e-12
# PCG iteration 1400 complete. Residual norm = 1.7190028914204625e-11
# PCG iteration 1500 complete. Residual norm = 2.3708459240961988e-12
# PCG iteration 1600 complete. Residual norm = 1.4850926044474022e-11
# PCG iteration 1700 complete. Residual norm = 1.0432765762402596e-12
# PCG iteration 1800 complete. Residual norm = 1.2486273950548799e-12
# PCG iteration 1900 complete. Residual norm = 7.938943691896197e-14
# PCG iteration 2000 complete. Residual norm = 1.8957840126291453e-13
# PCG iteration 2100 complete. Residual norm = 2.810170444868948e-13
# PCG iteration 2200 complete. Residual norm = 6.802087240903934e-14
# PCG iteration 2300 complete. Residual norm = 3.009530084451158e-14
# PCG iteration 2400 complete. Residual norm = 1.2869873657723411e-14
# PCG iteration 2500 complete. Residual norm = 1.067310980264538e-14
# PCG iteration 2600 complete. Residual norm = 5.3038251247243106e-15
# PCG iteration 2700 complete. Residual norm = 2.8997781196512867e-15
# PCG iteration 2800 complete. Residual norm = 9.538991766819944e-16
# Iteration 15 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 8.242285187698428e-10
# PCG iteration 100 complete. Residual norm = 9.7834484957815e-10
# PCG iteration 200 complete. Residual norm = 2.4493493344657224e-10
# PCG iteration 300 complete. Residual norm = 5.740326547432062e-10
# PCG iteration 400 complete. Residual norm = 3.752635424625339e-10
# PCG iteration 500 complete. Residual norm = 1.7923371120609488e-10
# PCG iteration 600 complete. Residual norm = 2.530835818692623e-10
# PCG iteration 700 complete. Residual norm = 2.1994596421937018e-10
# PCG iteration 800 complete. Residual norm = 5.714775180853948e-11
# PCG iteration 900 complete. Residual norm = 1.6713470885054704e-11
# PCG iteration 1000 complete. Residual norm = 1.4540837978138654e-10
# PCG iteration 1100 complete. Residual norm = 8.687456309885988e-11
# PCG iteration 1200 complete. Residual norm = 1.0307825773492318e-11
# PCG iteration 1300 complete. Residual norm = 2.0471548067835244e-11
# PCG iteration 1400 complete. Residual norm = 2.8939493162960517e-11
# PCG iteration 1500 complete. Residual norm = 7.985342422023312e-12
# PCG iteration 1600 complete. Residual norm = 2.2408897654146998e-12
# PCG iteration 1700 complete. Residual norm = 3.085767318750099e-12
# PCG iteration 1800 complete. Residual norm = 2.9743358383876872e-12
# PCG iteration 1900 complete. Residual norm = 1.5240024953816489e-12
# PCG iteration 2000 complete. Residual norm = 8.515807958971167e-13
# PCG iteration 2100 complete. Residual norm = 9.18596145330075e-13
# PCG iteration 2200 complete. Residual norm = 1.798223706441296e-13
# PCG iteration 2300 complete. Residual norm = 2.5433862372963023e-13
# PCG iteration 2400 complete. Residual norm = 4.464118419540697e-14
# PCG iteration 2500 complete. Residual norm = 3.416874327422971e-14
# PCG iteration 2600 complete. Residual norm = 1.6004728195951473e-14
# PCG iteration 2700 complete. Residual norm = 5.58836075000333e-16
# PCG iteration 2800 complete. Residual norm = 9.262135871636323e-16
# PCG iteration 2900 complete. Residual norm = 3.4892749344576533e-15
# Warning: PCG did not converge to tolerance. Tolerance was 1e-16 but norm of residual is 2.438637077781811e-15
# Iteration 16 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 3.0541738582634537e-10
# PCG iteration 100 complete. Residual norm = 1.2929405324157983e-09
# PCG iteration 200 complete. Residual norm = 1.0068600397872274e-09
# PCG iteration 300 complete. Residual norm = 3.0844013454434105e-10
# PCG iteration 400 complete. Residual norm = 1.4821730509595454e-09
# PCG iteration 500 complete. Residual norm = 1.6592659191072556e-10
# PCG iteration 600 complete. Residual norm = 4.817181098459855e-10
# PCG iteration 700 complete. Residual norm = 2.2537022248414473e-10
# PCG iteration 800 complete. Residual norm = 6.5557261008653e-11
# PCG iteration 900 complete. Residual norm = 6.384521383795416e-11
# PCG iteration 1000 complete. Residual norm = 1.3164304715762576e-11
# PCG iteration 1100 complete. Residual norm = 5.540456288199991e-11
# PCG iteration 1200 complete. Residual norm = 8.38679889425542e-11
# PCG iteration 1300 complete. Residual norm = 1.836759043472025e-11
# PCG iteration 1400 complete. Residual norm = 4.78205365930795e-12
# PCG iteration 1500 complete. Residual norm = 8.915070938420033e-12
# PCG iteration 1600 complete. Residual norm = 5.625618460652904e-12
# PCG iteration 1700 complete. Residual norm = 2.290194292889347e-12
# PCG iteration 1800 complete. Residual norm = 4.608383444813791e-13
# PCG iteration 1900 complete. Residual norm = 4.240974162562222e-13
# PCG iteration 2000 complete. Residual norm = 3.2108809968484087e-12
# PCG iteration 2100 complete. Residual norm = 1.822757656616547e-12
# PCG iteration 2200 complete. Residual norm = 1.968610414656083e-13
# PCG iteration 2300 complete. Residual norm = 5.214180324487894e-14
# PCG iteration 2400 complete. Residual norm = 2.542007708115305e-14
# PCG iteration 2500 complete. Residual norm = 1.585333545618987e-15
# PCG iteration 2600 complete. Residual norm = 2.3364777045628907e-15
# PCG iteration 2700 complete. Residual norm = 5.831465558612419e-16
# PCG iteration 2800 complete. Residual norm = 5.8312382361452e-15
# PCG iteration 2900 complete. Residual norm = 3.629675939420974e-15
# Warning: PCG did not converge to tolerance. Tolerance was 1e-16 but norm of residual is 1.6363744804711103e-15
# Iteration 17 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 5.314599316186275e-10
# PCG iteration 100 complete. Residual norm = 4.0084086050384826e-10
# PCG iteration 200 complete. Residual norm = 7.917529964984737e-10
# PCG iteration 300 complete. Residual norm = 2.113882402454692e-10
# PCG iteration 400 complete. Residual norm = 8.477843982390709e-10
# PCG iteration 500 complete. Residual norm = 7.646453470400161e-10
# PCG iteration 600 complete. Residual norm = 2.330495241231745e-10
# PCG iteration 700 complete. Residual norm = 1.6356974108511224e-10
# PCG iteration 800 complete. Residual norm = 1.244230551922243e-10
# PCG iteration 900 complete. Residual norm = 4.8139849745387764e-11
# PCG iteration 1000 complete. Residual norm = 1.1115050546628424e-10
# PCG iteration 1100 complete. Residual norm = 2.308382825166877e-11
# PCG iteration 1200 complete. Residual norm = 2.5148048574119564e-11
# PCG iteration 1300 complete. Residual norm = 3.714632074158786e-11
# PCG iteration 1400 complete. Residual norm = 1.2061452531186845e-11
# PCG iteration 1500 complete. Residual norm = 3.901687133101017e-12
# PCG iteration 1600 complete. Residual norm = 2.1314941998917813e-12
# PCG iteration 1700 complete. Residual norm = 5.20298084130677e-12
# PCG iteration 1800 complete. Residual norm = 3.496065199490306e-12
# PCG iteration 1900 complete. Residual norm = 3.1010434563098765e-13
# PCG iteration 2000 complete. Residual norm = 1.4823796216142243e-13
# PCG iteration 2100 complete. Residual norm = 5.118169343204526e-13
# PCG iteration 2200 complete. Residual norm = 4.4533964732064446e-13
# PCG iteration 2300 complete. Residual norm = 4.613466929987396e-14
# PCG iteration 2400 complete. Residual norm = 3.155097101008135e-14
# PCG iteration 2500 complete. Residual norm = 6.493735314961257e-15
# PCG iteration 2600 complete. Residual norm = 2.1760994275385774e-15
# PCG iteration 2700 complete. Residual norm = 8.550227972875133e-16
# PCG iteration 2800 complete. Residual norm = 1.6144029752149258e-15
# PCG iteration 2900 complete. Residual norm = 2.6948956727870484e-15
# Warning: PCG did not converge to tolerance. Tolerance was 1e-16 but norm of residual is 1.5401780074426235e-15
# Iteration 18 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 6.672501995375058e-10
# PCG iteration 100 complete. Residual norm = 2.6515192264042753e-09
# PCG iteration 200 complete. Residual norm = 7.538867863310372e-10
# PCG iteration 300 complete. Residual norm = 2.3033307205988507e-10
# PCG iteration 400 complete. Residual norm = 5.520753298959846e-10
# PCG iteration 500 complete. Residual norm = 1.279969907841405e-09
# PCG iteration 600 complete. Residual norm = 1.371174701558786e-10
# PCG iteration 700 complete. Residual norm = 1.0103207159772865e-10
# PCG iteration 800 complete. Residual norm = 2.056140327444389e-11
# PCG iteration 900 complete. Residual norm = 5.2799507821443825e-11
# PCG iteration 1000 complete. Residual norm = 9.777862547410976e-11
# PCG iteration 1100 complete. Residual norm = 2.2181067746429584e-11
# PCG iteration 1200 complete. Residual norm = 1.4504975345830395e-11
# PCG iteration 1300 complete. Residual norm = 4.748639849394554e-12
# PCG iteration 1400 complete. Residual norm = 9.74459922475912e-12
# PCG iteration 1500 complete. Residual norm = 7.91442692632538e-12
# PCG iteration 1600 complete. Residual norm = 7.971251263227952e-12
# PCG iteration 1700 complete. Residual norm = 3.5471335070591525e-12
# PCG iteration 1800 complete. Residual norm = 8.670701960242222e-13
# PCG iteration 1900 complete. Residual norm = 2.6983246908564296e-13
# PCG iteration 2000 complete. Residual norm = 5.874267543747036e-13
# PCG iteration 2100 complete. Residual norm = 3.4718842384373616e-13
# PCG iteration 2200 complete. Residual norm = 1.0267533486841077e-13
# PCG iteration 2300 complete. Residual norm = 8.686719285512165e-14
# PCG iteration 2400 complete. Residual norm = 7.02841385148722e-15
# PCG iteration 2500 complete. Residual norm = 5.545648796000677e-15
# PCG iteration 2600 complete. Residual norm = 4.2359545944948163e-16
# PCG iteration 2700 complete. Residual norm = 5.722705469393783e-16
# PCG iteration 2800 complete. Residual norm = 4.516092742349047e-16
# Iteration 19 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 2.448070079985598e-10
# PCG iteration 100 complete. Residual norm = 4.094384553621211e-10
# PCG iteration 200 complete. Residual norm = 1.1450020931391691e-09
# PCG iteration 300 complete. Residual norm = 7.382612854378579e-10
# PCG iteration 400 complete. Residual norm = 1.4904757983380534e-10
# PCG iteration 500 complete. Residual norm = 7.308743055212119e-10
# PCG iteration 600 complete. Residual norm = 4.193160818566355e-10
# PCG iteration 700 complete. Residual norm = 2.8485971914626873e-10
# PCG iteration 800 complete. Residual norm = 1.5238826867047806e-10
# PCG iteration 900 complete. Residual norm = 5.3441126524056415e-11
# PCG iteration 1000 complete. Residual norm = 2.8122898107496574e-11
# PCG iteration 1100 complete. Residual norm = 5.6855620905738036e-11
# PCG iteration 1200 complete. Residual norm = 3.9634087678486196e-11
# PCG iteration 1300 complete. Residual norm = 2.1299512500960738e-11
# PCG iteration 1400 complete. Residual norm = 4.328709699713551e-12
# PCG iteration 1500 complete. Residual norm = 1.1396854814049728e-11
# PCG iteration 1600 complete. Residual norm = 5.366648423398013e-13
# PCG iteration 1700 complete. Residual norm = 1.884176408645244e-12
# PCG iteration 1800 complete. Residual norm = 2.84080875143089e-12
# PCG iteration 1900 complete. Residual norm = 2.453218617831654e-12
# PCG iteration 2000 complete. Residual norm = 2.6348985927154844e-13
# PCG iteration 2100 complete. Residual norm = 6.851559792610262e-13
# PCG iteration 2200 complete. Residual norm = 3.4067673270084253e-13
# PCG iteration 2300 complete. Residual norm = 2.575003029542649e-14
# PCG iteration 2400 complete. Residual norm = 5.098083617044967e-14
# PCG iteration 2500 complete. Residual norm = 1.0544802098828247e-14
# PCG iteration 2600 complete. Residual norm = 1.3097683168887455e-14
# PCG iteration 2700 complete. Residual norm = 1.877576641322429e-15
# PCG iteration 2800 complete. Residual norm = 3.4446992962128037e-16
# PCG iteration 2900 complete. Residual norm = 1.466391590978762e-15
# Warning: PCG did not converge to tolerance. Tolerance was 1e-16 but norm of residual is 9.358185172690225e-16
# Iteration 20 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 3.113850566283105e-10
# PCG iteration 100 complete. Residual norm = 1.270664018448997e-09
# PCG iteration 200 complete. Residual norm = 1.085761147656683e-09
# PCG iteration 300 complete. Residual norm = 4.3956527306932003e-10
# PCG iteration 400 complete. Residual norm = 5.010279968686859e-10
# PCG iteration 500 complete. Residual norm = 5.5625979517026636e-11
# PCG iteration 600 complete. Residual norm = 5.185948337427249e-10
# PCG iteration 700 complete. Residual norm = 1.9657130090333652e-10
# PCG iteration 800 complete. Residual norm = 5.2439778214230515e-11
# PCG iteration 900 complete. Residual norm = 1.2559130124767393e-10
# PCG iteration 1000 complete. Residual norm = 4.5999169751009816e-11
# PCG iteration 1100 complete. Residual norm = 2.7922863674034737e-11
# PCG iteration 1200 complete. Residual norm = 3.3141264038638596e-11
# PCG iteration 1300 complete. Residual norm = 5.548446251057992e-12
# PCG iteration 1400 complete. Residual norm = 1.4182475506496761e-11
# PCG iteration 1500 complete. Residual norm = 1.106851849758117e-11
# PCG iteration 1600 complete. Residual norm = 6.370617575135462e-12
# PCG iteration 1700 complete. Residual norm = 1.0678590173576752e-12
# PCG iteration 1800 complete. Residual norm = 2.2485198382035665e-13
# PCG iteration 1900 complete. Residual norm = 3.2572206108520685e-13
# PCG iteration 2000 complete. Residual norm = 5.497470968035545e-13
# PCG iteration 2100 complete. Residual norm = 2.0051301385329984e-13
# PCG iteration 2200 complete. Residual norm = 5.176653918893825e-13
# PCG iteration 2300 complete. Residual norm = 8.651831014854297e-14
# PCG iteration 2400 complete. Residual norm = 1.2575871062830285e-14
# PCG iteration 2500 complete. Residual norm = 2.4686967947722084e-15
# PCG iteration 2600 complete. Residual norm = 1.3796412293780552e-15
# PCG iteration 2700 complete. Residual norm = 3.945316837984658e-15
# PCG iteration 2800 complete. Residual norm = 4.675410110606924e-16
# Iteration 21 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 9.743488238456166e-10
# PCG iteration 100 complete. Residual norm = 9.292536740090895e-10
# PCG iteration 200 complete. Residual norm = 4.922989793598731e-10
# PCG iteration 300 complete. Residual norm = 8.582923261002406e-10
# PCG iteration 400 complete. Residual norm = 4.088717697747768e-10
# PCG iteration 500 complete. Residual norm = 3.859562947017281e-10
# PCG iteration 600 complete. Residual norm = 2.977698643213955e-10
# PCG iteration 700 complete. Residual norm = 2.2249860287537615e-10
# PCG iteration 800 complete. Residual norm = 1.578519398526268e-10
# PCG iteration 900 complete. Residual norm = 2.7895663556876116e-10
# PCG iteration 1000 complete. Residual norm = 9.738731522601629e-12
# PCG iteration 1100 complete. Residual norm = 1.083713847827017e-11
# PCG iteration 1200 complete. Residual norm = 3.031246694623624e-12
# PCG iteration 1300 complete. Residual norm = 1.7120904303655204e-12
# PCG iteration 1400 complete. Residual norm = 8.190500686532098e-13
# PCG iteration 1500 complete. Residual norm = 7.400432263521273e-13
# PCG iteration 1600 complete. Residual norm = 1.7500536610148831e-12
# PCG iteration 1700 complete. Residual norm = 1.6106036860100148e-12
# PCG iteration 1800 complete. Residual norm = 5.861477752819311e-13
# PCG iteration 1900 complete. Residual norm = 1.9746807270945577e-13
# PCG iteration 2000 complete. Residual norm = 4.6762639198177566e-14
# PCG iteration 2100 complete. Residual norm = 2.363465868328307e-13
# PCG iteration 2200 complete. Residual norm = 4.732466588747153e-13
# PCG iteration 2300 complete. Residual norm = 2.2731117118798827e-13
# PCG iteration 2400 complete. Residual norm = 2.5404911803265408e-14
# PCG iteration 2500 complete. Residual norm = 1.24591168884137e-14
# PCG iteration 2600 complete. Residual norm = 5.920095380443965e-15
# PCG iteration 2700 complete. Residual norm = 1.5904078658961034e-14
# PCG iteration 2800 complete. Residual norm = 2.6404968875737723e-15
# PCG iteration 2900 complete. Residual norm = 5.37556415667554e-15
# Warning: PCG did not converge to tolerance. Tolerance was 1e-16 but norm of residual is 2.32318182838984e-15
# Iteration 22 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 5.074310416297578e-10
# ...
# PCG iteration 2000 complete. Residual norm = 6.126767062436533e-12
# PCG iteration 2100 complete. Residual norm = 1.5641080444717126e-11
# PCG iteration 2200 complete. Residual norm = 2.6306875514775507e-12
# PCG iteration 2300 complete. Residual norm = 9.381532876939769e-12
# PCG iteration 2400 complete. Residual norm = 2.2266469917875398e-11
# PCG iteration 2500 complete. Residual norm = 1.6466928732042363e-12
# PCG iteration 2600 complete. Residual norm = 1.136540622899418e-12
# PCG iteration 2700 complete. Residual norm = 5.371322554488869e-14
# PCG iteration 2800 complete. Residual norm = 1.7404700185415234e-13
# PCG iteration 2900 complete. Residual norm = 1.702023396353558e-13
# Warning: PCG did not converge to tolerance. Tolerance was 1e-16 but norm of residual is 2.1349667029386087e-14
# Iteration 42 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 3.289521710581056e-10
# PCG iteration 100 complete. Residual norm = 3.888951383146377e-09
# PCG iteration 200 complete. Residual norm = 4.622057736547447e-10
# PCG iteration 300 complete. Residual norm = 1.4511584156551294e-09
# PCG iteration 400 complete. Residual norm = 5.778227896158228e-10
# PCG iteration 500 complete. Residual norm = 2.4209509397188356e-10
# PCG iteration 600 complete. Residual norm = 7.490220249595225e-11
# PCG iteration 700 complete. Residual norm = 3.8562125714847184e-10
# PCG iteration 800 complete. Residual norm = 1.2712411678883484e-10
# PCG iteration 900 complete. Residual norm = 4.1299749731216195e-10
# PCG iteration 1000 complete. Residual norm = 1.2713279040621472e-10
# PCG iteration 1100 complete. Residual norm = 2.3317786590482115e-10
# PCG iteration 1200 complete. Residual norm = 3.3421272693789916e-11
# PCG iteration 1300 complete. Residual norm = 7.943756069606067e-11
# PCG iteration 1400 complete. Residual norm = 7.577161120764231e-11
# PCG iteration 1500 complete. Residual norm = 2.7597344548491165e-11
# PCG iteration 1600 complete. Residual norm = 1.7494944382079325e-10
# PCG iteration 1700 complete. Residual norm = 3.6950258824886006e-11
# PCG iteration 1800 complete. Residual norm = 3.69490098239833e-11
# PCG iteration 1900 complete. Residual norm = 1.384064043929989e-11
# PCG iteration 2000 complete. Residual norm = 2.4323838082596083e-11
# PCG iteration 2100 complete. Residual norm = 3.5916029265253835e-12
# PCG iteration 2200 complete. Residual norm = 1.3420216327109102e-11
# PCG iteration 2300 complete. Residual norm = 3.4414686812117568e-12
# PCG iteration 2400 complete. Residual norm = 7.058758959288536e-12
# PCG iteration 2500 complete. Residual norm = 7.56811974200744e-12
# PCG iteration 2600 complete. Residual norm = 9.02169642160236e-14
# PCG iteration 2700 complete. Residual norm = 1.9099220089583563e-13
# PCG iteration 2800 complete. Residual norm = 1.002718449992588e-14
# PCG iteration 2900 complete. Residual norm = 2.9174288039644086e-14
# Warning: PCG did not converge to tolerance. Tolerance was 1e-16 but norm of residual is 5.991873799427241e-14
# Iteration 43 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 7.953996350451575e-10
# PCG iteration 100 complete. Residual norm = 2.3930182280196277e-09
# PCG iteration 200 complete. Residual norm = 6.64982124920499e-10
# PCG iteration 300 complete. Residual norm = 8.674107265793651e-11
# PCG iteration 400 complete. Residual norm = 4.850951862422903e-10
# PCG iteration 500 complete. Residual norm = 1.7626400339310067e-10
# PCG iteration 600 complete. Residual norm = 2.9758401298707327e-10
# PCG iteration 700 complete. Residual norm = 3.414148685987328e-10
# PCG iteration 800 complete. Residual norm = 2.8120972217493545e-10
# PCG iteration 900 complete. Residual norm = 3.4997429954053416e-10
# PCG iteration 1000 complete. Residual norm = 5.94982119128673e-10
# PCG iteration 1100 complete. Residual norm = 3.410369209255748e-11
# PCG iteration 1200 complete. Residual norm = 4.095807720760902e-11
# PCG iteration 1300 complete. Residual norm = 3.0895744296266514e-11
# PCG iteration 1400 complete. Residual norm = 1.882171848932579e-11
# PCG iteration 1500 complete. Residual norm = 3.2978269420835815e-11
# PCG iteration 1600 complete. Residual norm = 4.522395999351225e-11
# PCG iteration 1700 complete. Residual norm = 5.8130493474362055e-11
# PCG iteration 1800 complete. Residual norm = 2.3569420720681578e-11
# PCG iteration 1900 complete. Residual norm = 1.4293316530356037e-11
# PCG iteration 2000 complete. Residual norm = 1.2176480310155391e-11
# PCG iteration 2100 complete. Residual norm = 1.334419987703006e-11
# PCG iteration 2200 complete. Residual norm = 3.1576768109997655e-12
# PCG iteration 2300 complete. Residual norm = 1.5701951891489152e-11
# PCG iteration 2400 complete. Residual norm = 4.383510481681396e-12
# PCG iteration 2500 complete. Residual norm = 6.508185917269982e-12
# PCG iteration 2600 complete. Residual norm = 5.773117444166087e-13
# PCG iteration 2700 complete. Residual norm = 4.1824332083599536e-13
# PCG iteration 2800 complete. Residual norm = 8.203130557639382e-14
# PCG iteration 2900 complete. Residual norm = 1.1267272074925224e-14
# Warning: PCG did not converge to tolerance. Tolerance was 1e-16 but norm of residual is 1.147289728498091e-13
# Iteration 44 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 4.1198827682720207e-10
# PCG iteration 100 complete. Residual norm = 1.3135151855081517e-09
# PCG iteration 200 complete. Residual norm = 1.943781136048983e-09
# PCG iteration 300 complete. Residual norm = 4.576640455500325e-11
# PCG iteration 400 complete. Residual norm = 2.7807420255321347e-10
# PCG iteration 500 complete. Residual norm = 6.026556476079747e-10
# PCG iteration 600 complete. Residual norm = 9.624390173712527e-10
# PCG iteration 700 complete. Residual norm = 2.922904140945093e-10
# PCG iteration 800 complete. Residual norm = 5.044404893794763e-10
# PCG iteration 900 complete. Residual norm = 5.094242250258674e-10
# PCG iteration 1000 complete. Residual norm = 1.515360892323514e-10
# PCG iteration 1100 complete. Residual norm = 9.388049365677276e-11
# PCG iteration 1200 complete. Residual norm = 1.722018361238753e-10
# PCG iteration 1300 complete. Residual norm = 5.57326441941175e-11
# PCG iteration 1400 complete. Residual norm = 5.823111437486261e-11
# PCG iteration 1500 complete. Residual norm = 2.6867424951504404e-10
# PCG iteration 1600 complete. Residual norm = 2.7165603100343105e-11
# PCG iteration 1700 complete. Residual norm = 4.082693905171908e-11
# PCG iteration 1800 complete. Residual norm = 4.547821494393922e-11
# PCG iteration 1900 complete. Residual norm = 8.126387063267515e-11
# PCG iteration 2000 complete. Residual norm = 3.2039770142544555e-12
# PCG iteration 2100 complete. Residual norm = 2.448318674533323e-12
# PCG iteration 2200 complete. Residual norm = 4.856023135685339e-12
# PCG iteration 2300 complete. Residual norm = 5.0177285937369476e-11
# PCG iteration 2400 complete. Residual norm = 1.1031640878567117e-11
# PCG iteration 2500 complete. Residual norm = 3.1452139070270446e-12
# PCG iteration 2600 complete. Residual norm = 4.996334942997116e-12
# PCG iteration 2700 complete. Residual norm = 7.471880644586981e-13
# PCG iteration 2800 complete. Residual norm = 1.7359791176178169e-13
# PCG iteration 2900 complete. Residual norm = 4.063282371159771e-13
# Warning: PCG did not converge to tolerance. Tolerance was 1e-16 but norm of residual is 5.152042529578404e-13
# Iteration 45 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 5.670544589442272e-10
# PCG iteration 100 complete. Residual norm = 9.92703586000232e-10
# PCG iteration 200 complete. Residual norm = 9.391473154707342e-10
# PCG iteration 300 complete. Residual norm = 1.1555785217609582e-09
# PCG iteration 400 complete. Residual norm = 9.82008141470203e-10
# PCG iteration 500 complete. Residual norm = 5.117237744656222e-10
# PCG iteration 600 complete. Residual norm = 6.263267682271589e-10
# PCG iteration 700 complete. Residual norm = 6.909121885723124e-11
# PCG iteration 800 complete. Residual norm = 7.681354163846521e-11
# PCG iteration 900 complete. Residual norm = 1.416774614293459e-10
# PCG iteration 1000 complete. Residual norm = 6.943384756041837e-10
# PCG iteration 1100 complete. Residual norm = 8.033251841510491e-11
# PCG iteration 1200 complete. Residual norm = 8.315017424598281e-11
# PCG iteration 1300 complete. Residual norm = 1.4728039621214606e-10
# PCG iteration 1400 complete. Residual norm = 2.6788798609955755e-11
# PCG iteration 1500 complete. Residual norm = 7.520173372910222e-11
# PCG iteration 1600 complete. Residual norm = 1.6745998684952745e-11
# PCG iteration 1700 complete. Residual norm = 1.9263448475248524e-11
# PCG iteration 1800 complete. Residual norm = 2.5498386388433936e-11
# PCG iteration 1900 complete. Residual norm = 4.1681821189021306e-11
# PCG iteration 2000 complete. Residual norm = 1.3344392431335894e-11
# PCG iteration 2100 complete. Residual norm = 1.815109000602444e-11
# PCG iteration 2200 complete. Residual norm = 2.4253890996278615e-12
# PCG iteration 2300 complete. Residual norm = 1.492535695729602e-12
# PCG iteration 2400 complete. Residual norm = 2.488856560081687e-12
# PCG iteration 2500 complete. Residual norm = 4.58411563916683e-12
# PCG iteration 2600 complete. Residual norm = 3.2755272019041604e-12
# PCG iteration 2700 complete. Residual norm = 2.7519284594157423e-13
# PCG iteration 2800 complete. Residual norm = 6.409614185980475e-14
# PCG iteration 2900 complete. Residual norm = 9.877958639849943e-14
# Warning: PCG did not converge to tolerance. Tolerance was 1e-16 but norm of residual is 1.0432391170552002e-13
# Iteration 46 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 6.334540669783451e-10
# PCG iteration 100 complete. Residual norm = 2.8732585199975347e-09
# PCG iteration 200 complete. Residual norm = 2.443276414521023e-10
# PCG iteration 300 complete. Residual norm = 1.0294077812389446e-09
# PCG iteration 400 complete. Residual norm = 2.19217519137338e-10
# PCG iteration 500 complete. Residual norm = 2.6954249943145214e-10
# PCG iteration 600 complete. Residual norm = 9.012753876547208e-10
# PCG iteration 700 complete. Residual norm = 4.039826528856594e-10
# PCG iteration 800 complete. Residual norm = 1.457700626872338e-10
# PCG iteration 900 complete. Residual norm = 1.075009178896913e-10
# PCG iteration 1000 complete. Residual norm = 2.3194390852410152e-10
# PCG iteration 1100 complete. Residual norm = 5.882579146021527e-11
# PCG iteration 1200 complete. Residual norm = 7.905180676726076e-11
# PCG iteration 1300 complete. Residual norm = 5.100300043414663e-11
# PCG iteration 1400 complete. Residual norm = 2.9460808792514115e-11
# PCG iteration 1500 complete. Residual norm = 9.743496287573095e-11
# PCG iteration 1600 complete. Residual norm = 3.1466485667097643e-11
# PCG iteration 1700 complete. Residual norm = 2.9812086826952466e-11
# PCG iteration 1800 complete. Residual norm = 1.150134241317824e-11
# PCG iteration 1900 complete. Residual norm = 2.788855301208426e-12
# PCG iteration 2000 complete. Residual norm = 1.9597747036304014e-11
# PCG iteration 2100 complete. Residual norm = 1.3391670584950166e-11
# PCG iteration 2200 complete. Residual norm = 7.783709440878361e-12
# PCG iteration 2300 complete. Residual norm = 1.05051418952673e-11
# PCG iteration 2400 complete. Residual norm = 5.5166513718285515e-12
# PCG iteration 2500 complete. Residual norm = 9.42988959487523e-13
# PCG iteration 2600 complete. Residual norm = 1.866209687869172e-13
# PCG iteration 2700 complete. Residual norm = 6.631560535083625e-14
# PCG iteration 2800 complete. Residual norm = 1.391258798704581e-13
# PCG iteration 2900 complete. Residual norm = 1.0098982739480122e-13
# Warning: PCG did not converge to tolerance. Tolerance was 1e-16 but norm of residual is 6.787092047232102e-14
# Iteration 47 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 8.260766515277851e-10
# PCG iteration 100 complete. Residual norm = 1.0470395661599241e-09
# PCG iteration 200 complete. Residual norm = 7.886466479867238e-10
# PCG iteration 300 complete. Residual norm = 1.008168659666353e-09
# PCG iteration 400 complete. Residual norm = 6.969489985131361e-10
# PCG iteration 500 complete. Residual norm = 2.700931422960906e-10
# PCG iteration 600 complete. Residual norm = 6.249357697996061e-10
# PCG iteration 700 complete. Residual norm = 2.1717995457581907e-10
# PCG iteration 800 complete. Residual norm = 1.5764939353957175e-10
# PCG iteration 900 complete. Residual norm = 1.1590609722000877e-10
# PCG iteration 1000 complete. Residual norm = 4.1647882365047906e-10
# PCG iteration 1100 complete. Residual norm = 6.471004981856154e-11
# PCG iteration 1200 complete. Residual norm = 2.5412191795304295e-10
# PCG iteration 1300 complete. Residual norm = 6.329356483369963e-11
# PCG iteration 1400 complete. Residual norm = 5.2706238679034456e-11
# PCG iteration 1500 complete. Residual norm = 1.0134854067089805e-10
# PCG iteration 1600 complete. Residual norm = 2.7523251039385244e-11
# PCG iteration 1700 complete. Residual norm = 1.770160580616409e-11
# PCG iteration 1800 complete. Residual norm = 5.0301120907425556e-11
# PCG iteration 1900 complete. Residual norm = 2.6644141754017525e-11
# PCG iteration 2000 complete. Residual norm = 2.0339502651567365e-11
# PCG iteration 2100 complete. Residual norm = 6.181978106506447e-12
# PCG iteration 2200 complete. Residual norm = 3.5886859890005285e-12
# PCG iteration 2300 complete. Residual norm = 1.331958848771464e-12
# PCG iteration 2400 complete. Residual norm = 1.5144707319822426e-12
# PCG iteration 2500 complete. Residual norm = 1.1593003033244509e-12
# PCG iteration 2600 complete. Residual norm = 1.9656265547521312e-13
# PCG iteration 2700 complete. Residual norm = 1.4686250262782585e-12
# PCG iteration 2800 complete. Residual norm = 8.160227051370872e-13
# PCG iteration 2900 complete. Residual norm = 7.506746146999227e-14
# Warning: PCG did not converge to tolerance. Tolerance was 1e-16 but norm of residual is 1.1934519738025957e-14
# Iteration 48 | Loss: 0.00011580778664210811
# PCG iteration 0 complete. Residual norm = 8.689819974705415e-10
# PCG iteration 100 complete. Residual norm = 4.511961915198981e-09
# PCG iteration 200 complete. Residual norm = 1.3035844625974846e-10
# PCG iteration 300 complete. Residual norm = 2.3197971321664568e-10
# PCG iteration 400 complete. Residual norm = 1.9508474835561174e-09
# PCG iteration 500 complete. Residual norm = 9.278640078491662e-10
# PCG iteration 600 complete. Residual norm = 6.660686446835484e-10
# PCG iteration 700 complete. Residual norm = 6.201029134622615e-10
# PCG iteration 800 complete. Residual norm = 1.1257213911042285e-10
# PCG iteration 900 complete. Residual norm = 4.5640555224046864e-10
# PCG iteration 1000 complete. Residual norm = 1.2012016381568458e-10
# PCG iteration 1100 complete. Residual norm = 1.1745533712304024e-10
# PCG iteration 1200 complete. Residual norm = 1.8403466250926925e-10
# PCG iteration 1300 complete. Residual norm = 1.659969939282746e-10
# PCG iteration 1400 complete. Residual norm = 8.46881037519509e-11
# PCG iteration 1500 complete. Residual norm = 2.3226223028194326e-11
# PCG iteration 1600 complete. Residual norm = 1.0768836516961144e-10
# PCG iteration 1700 complete. Residual norm = 1.0210794883225294e-11
# PCG iteration 1800 complete. Residual norm = 1.1935949624508613e-11
# PCG iteration 1900 complete. Residual norm = 2.301176089958279e-11
# PCG iteration 2000 complete. Residual norm = 3.00637952033167e-11
# PCG iteration 2100 complete. Residual norm = 3.1051105697094128e-12
# PCG iteration 2200 complete. Residual norm = 3.629226259793672e-12
# PCG iteration 2300 complete. Residual norm = 6.5197357061730354e-12
# PCG iteration 2400 complete. Residual norm = 4.458616635616419e-12
# PCG iteration 2500 complete. Residual norm = 5.5551670034847955e-12
# PCG iteration 2600 complete. Residual norm = 2.356953607979273e-12
# PCG iteration 2700 complete. Residual norm = 3.9867271268111126e-13
# PCG iteration 2800 complete. Residual norm = 5.076612416034243e-13
# PCG iteration 2900 complete. Residual norm = 3.533449777887686e-14
# Warning: PCG did not converge to tolerance. Tolerance was 1e-16 but norm of residual is 3.7846096157152787e-14
# Iteration 49 | Loss: 0.00011580778664210811
